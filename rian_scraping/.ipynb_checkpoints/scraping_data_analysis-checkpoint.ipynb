# %%
import pandas as pd

# %%
sd1 = pd.read_csv("results_20240429_225800.csv")

# %%
df = pd.DataFrame(sd1)

# %%
sd1
# Out:
#                                                                  job_title  \
# 営業【月給29万以上！インセンティブ有！未経験OK！】                                 Only Life 株式会社
# 不動産営業（賃貸仲介・賃貸管理・売買仲介）                                      有限会社ハウスコーポレーション
# カウンターにて接客業                                                 有限会社ハウスコーポレーション
# 内定まで2週間！未経験OK！賃貸不動産のルームアドバイザー                              有限会社ハウスコーポレーション
# 営業（不動産賃貸売買仲介・賃貸物件管理）                                       有限会社ハウスコーポレーション
# ...                                                                    ...
# 技術アジャスター（自動車事故の調査など）完全週休２日制、土日休　■勤務地：山梨県他（全国拠点有）        あいおいニッセイ同和損害調査株式会社
# 100％反響営業！テレアポなし◎リゾート物件の仲介/業績賞与年3回！テレワーク需要で好調♪未経験OK           ロイヤルハウジンググループ
# 宮崎県で大手企業の新規事業立ち上げのサポート業務                            PhillipsConsulting株式会社
# 転職したら毎日に余裕ができた／年休126日（土日OK）／ほぼ毎日18時半退社／賃貸管理∋宇都宮東口店               株式会社ミニテック
# ★長崎北店勤務★テレアポ・飛び込み一切なし！100％問い合わせ対応の【完全反響型営業】※原則定時退社                  リック不動産
#
#                                                           company_name  \
# 営業【月給29万以上！インセンティブ有！未経験OK！】                                       法人営業
# 不動産営業（賃貸仲介・賃貸管理・売買仲介）                                            不動産営業
# カウンターにて接客業                                                   カウンター賃貸営業
# 内定まで2週間！未経験OK！賃貸不動産のルームアドバイザー                                  カウンター営業
# 営業（不動産賃貸売買仲介・賃貸物件管理）                                           カウンター営業
# ...                                                                ...
# 技術アジャスター（自動車事故の調査など）完全週休２日制、土日休　■勤務地：山梨県他（全国拠点有）              技術アジャスター
# 100％反響営業！テレアポなし◎リゾート物件の仲介/業績賞与年3回！テレワーク需要で好調♪未経験OK           不動産売買仲介営業
# 宮崎県で大手企業の新規事業立ち上げのサポート業務                            新規事業の立ち上げに関わる責任者候補
# 転職したら毎日に余裕ができた／年休126日（土日OK）／ほぼ毎日18時半退社／賃貸管理∋宇都宮東口店          賃貸経営アドバイザー
# ★長崎北店勤務★テレアポ・飛び込み一切なし！100％問い合わせ対応の【完全反響型営業】※原則定時退社              営業スタッフ
#
#                                                        work_genre  \
# 営業【月給29万以上！インセンティブ有！未経験OK！】                         ('北海道札幌市北区',)
# 不動産営業（賃貸仲介・賃貸管理・売買仲介）                                 ('兵庫県尼崎市',)
# カウンターにて接客業                                            ('兵庫県尼崎市',)
# 内定まで2週間！未経験OK！賃貸不動産のルームアドバイザー                         ('兵庫県尼崎市',)
# 営業（不動産賃貸売買仲介・賃貸物件管理）                                  ('兵庫県尼崎市',)
# ...                                                           ...
# 技術アジャスター（自動車事故の調査など）完全週休２日制、土日休　■勤務地：山梨県他（全国拠点有）      ('山梨県甲府市',)
# 100％反響営業！テレアポなし◎リゾート物件の仲介/業績賞与年3回！テレワーク需要で好調♪未経験OK    ('静岡県伊東市',)
# 宮崎県で大手企業の新規事業立ち上げのサポート業務                              ('宮崎県宮崎市',)
# 転職したら毎日に余裕ができた／年休126日（土日OK）／ほぼ毎日18時半退社／賃貸管理∋宇都宮東口店   ('栃木県宇都宮市',)
# ★長崎北店勤務★テレアポ・飛び込み一切なし！100％問い合わせ対応の【完全反響型営業】※原則定時退社    ('長崎県長崎市',)
#
#                                                                       area  \
# 営業【月給29万以上！インセンティブ有！未経験OK！】                           ('月給 29万円 ～ 100万円',)
# 不動産営業（賃貸仲介・賃貸管理・売買仲介）                                       ('月給 25万円 ～',)
# カウンターにて接客業                                             ('月給 25万円 ～ 40万円',)
# 内定まで2週間！未経験OK！賃貸不動産のルームアドバイザー                          ('月給 25万円 ～ 80万円',)
# 営業（不動産賃貸売買仲介・賃貸物件管理）                                   ('月給 25万円 ～ 40万円',)
# ...                                                                    ...
# 技術アジャスター（自動車事故の調査など）完全週休２日制、土日休　■勤務地：山梨県他（全国拠点有）       ('月給 22万4,000円 ～',)
# 100％反響営業！テレアポなし◎リゾート物件の仲介/業績賞与年3回！テレワーク需要で好調♪未経験OK     ('月給 24万5,000円 ～',)
# 宮崎県で大手企業の新規事業立ち上げのサポート業務                            ('日給 1万円 ～ 1万6,000円',)
# 転職したら毎日に余裕ができた／年休126日（土日OK）／ほぼ毎日18時半退社／賃貸管理∋宇都宮東口店     ('月給 23万円 ～ 26万円',)
# ★長崎北店勤務★テレアポ・飛び込み一切なし！100％問い合わせ対応の【完全反響型営業】※原則定時退社     ('月給 22万円 ～ 27万円',)
#
#                                                                                                income  \
# 営業【月給29万以上！インセンティブ有！未経験OK！】                         ◎未経験の方には\n\nあなたのレベルに合わせて、簡単なお仕事からスタート。\n\n3~6ヶ...
# 不動産営業（賃貸仲介・賃貸管理・売買仲介）                               カウンター営業\n\nインターネットや住宅情報誌等を見て来店頂いたお客様への、売買物件の紹介...
# カウンターにて接客業                                          [1]カウンター営業\n\nインターネットや住宅情報誌等を見て来店頂いたお客様への、賃貸・売...
# 内定まで2週間！未経験OK！賃貸不動産のルームアドバイザー                       カウンター営業\n\nインターネットや住宅情報誌等を見て来店頂いたお客様への、売買物件の紹介...
# 営業（不動産賃貸売買仲介・賃貸物件管理）                                インターネットや住宅情報誌等を見て来店頂いたお客様への、賃貸・売買物件の紹介や案内業務。※反...
# ...                                                                                               ...
# 技術アジャスター（自動車事故の調査など）完全週休２日制、土日休　■勤務地：山梨県他（全国拠点有）    ▼事故解決をサポートします。\n\nあなたにお任せするのは、自動車保険に関する損害調査業務。...
# 100％反響営業！テレアポなし◎リゾート物件の仲介/業績賞与年3回！テレワーク需要で好調♪未経験OK  ☆創業448年！だから100％反響営業で大丈夫なんです。\n\n☆研修・サポート充実だから2...
# 宮崎県で大手企業の新規事業立ち上げのサポート業務                            ◎未経験者大歓迎\n\n未経験でも、将来的に、大手企業のコンサルティングを行っていただける為...
# 転職したら毎日に余裕ができた／年休126日（土日OK）／ほぼ毎日18時半退社／賃貸管理∋宇都宮東口店  ▼ほぼ定時帰り！繁忙期を除くと、残業時間は忙し店舗でも1日最長1時間ほどです\n▼ほとんどの...
# ★長崎北店勤務★テレアポ・飛び込み一切なし！100％問い合わせ対応の【完全反響型営業】※原則定時退社  ■賃貸営業（100％反響・来店型営業）\n\n　お部屋探しに来店されたお客様にお部屋をご案内...
#
#                                                                                           description  \
# 営業【月給29万以上！インセンティブ有！未経験OK！】                         https://en-gage.net/user/search/?area=0&job=10...
# 不動産営業（賃貸仲介・賃貸管理・売買仲介）                               https://en-gage.net/user/search/?area=0&job=10...
# カウンターにて接客業                                          https://en-gage.net/user/search/?area=0&job=10...
# 内定まで2週間！未経験OK！賃貸不動産のルームアドバイザー                       https://en-gage.net/user/search/?area=0&job=10...
# 営業（不動産賃貸売買仲介・賃貸物件管理）                                https://en-gage.net/user/search/?area=0&job=10...
# ...                                                                                               ...
# 技術アジャスター（自動車事故の調査など）完全週休２日制、土日休　■勤務地：山梨県他（全国拠点有）    https://en-gage.net/user/search/?area=0&job=30...
# 100％反響営業！テレアポなし◎リゾート物件の仲介/業績賞与年3回！テレワーク需要で好調♪未経験OK  https://en-gage.net/user/search/?area=0&job=30...
# 宮崎県で大手企業の新規事業立ち上げのサポート業務                            https://en-gage.net/user/search/?area=0&job=30...
# 転職したら毎日に余裕ができた／年休126日（土日OK）／ほぼ毎日18時半退社／賃貸管理∋宇都宮東口店  https://en-gage.net/user/search/?area=0&job=30...
# ★長崎北店勤務★テレアポ・飛び込み一切なし！100％問い合わせ対応の【完全反響型営業】※原則定時退社  https://en-gage.net/user/search/?area=0&job=30...
#
#                                                                      url
# 営業【月給29万以上！インセンティブ有！未経験OK！】                                          営業系
# 不動産営業（賃貸仲介・賃貸管理・売買仲介）                                                営業系
# カウンターにて接客業                                                           営業系
# 内定まで2週間！未経験OK！賃貸不動産のルームアドバイザー                                        営業系
# 営業（不動産賃貸売買仲介・賃貸物件管理）                                                 営業系
# ...                                                                  ...
# 技術アジャスター（自動車事故の調査など）完全週休２日制、土日休　■勤務地：山梨県他（全国拠点有）    専門職系（コンサルタント、金融、不動産）
# 100％反響営業！テレアポなし◎リゾート物件の仲介/業績賞与年3回！テレワーク需要で好調♪未経験OK  専門職系（コンサルタント、金融、不動産）
# 宮崎県で大手企業の新規事業立ち上げのサポート業務                            専門職系（コンサルタント、金融、不動産）
# 転職したら毎日に余裕ができた／年休126日（土日OK）／ほぼ毎日18時半退社／賃貸管理∋宇都宮東口店  専門職系（コンサルタント、金融、不動産）
# ★長崎北店勤務★テレアポ・飛び込み一切なし！100％問い合わせ対応の【完全反響型営業】※原則定時退社  専門職系（コンサルタント、金融、不動産）
#
# [1140 rows x 7 columns]

# %%
df.columns = ["job_title", "company_name", "work_genre", "area", "income", "description", "url", "job_type"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.columns = ["job_title", "company_name", "work_genre", "area", "income", "description", "url", "job_type"]
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:6002, in NDFrame.__setattr__(self, name, value)
#    6000 try:
#    6001     object.__getattribute__(self, name)
# -> 6002     return object.__setattr__(self, name, value)
#    6003 except AttributeError:
#    6004     pass
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:730, in NDFrame._set_axis(self, axis, labels)
#     725 """
#     726 This is called from the cython code when we set the `index` attribute
#     727 directly, e.g. `series.index = [1, 2, 3]`.
#     728 """
#     729 labels = ensure_index(labels)
# --> 730 self._mgr.set_axis(axis, labels)
#     731 self._clear_item_cache()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/internals/managers.py:225, in BaseBlockManager.set_axis(self, axis, new_labels)
#     223 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     224     # Caller is responsible for ensuring we have an Index object.
# --> 225     self._validate_set_axis(axis, new_labels)
#     226     self.axes[axis] = new_labels
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/internals/base.py:70, in DataManager._validate_set_axis(self, axis, new_labels)
#      67     pass
#      69 elif new_len != old_len:
# ---> 70     raise ValueError(
#      71         f"Length mismatch: Expected axis has {old_len} elements, new "
#      72         f"values have {new_len} elements"
#      73     )
#
# ValueError: Length mismatch: Expected axis has 7 elements, new values have 8 elements

# %%
df.iloc[:, 0]
# Out:
# 営業【月給29万以上！インセンティブ有！未経験OK！】                                   Only Life 株式会社
# 不動産営業（賃貸仲介・賃貸管理・売買仲介）                                        有限会社ハウスコーポレーション
# カウンターにて接客業                                                   有限会社ハウスコーポレーション
# 内定まで2週間！未経験OK！賃貸不動産のルームアドバイザー                                有限会社ハウスコーポレーション
# 営業（不動産賃貸売買仲介・賃貸物件管理）                                         有限会社ハウスコーポレーション
#                                                                ...
# 技術アジャスター（自動車事故の調査など）完全週休２日制、土日休　■勤務地：山梨県他（全国拠点有）          あいおいニッセイ同和損害調査株式会社
# 100％反響営業！テレアポなし◎リゾート物件の仲介/業績賞与年3回！テレワーク需要で好調♪未経験OK             ロイヤルハウジンググループ
# 宮崎県で大手企業の新規事業立ち上げのサポート業務                              PhillipsConsulting株式会社
# 転職したら毎日に余裕ができた／年休126日（土日OK）／ほぼ毎日18時半退社／賃貸管理∋宇都宮東口店                 株式会社ミニテック
# ★長崎北店勤務★テレアポ・飛び込み一切なし！100％問い合わせ対応の【完全反響型営業】※原則定時退社                    リック不動産
# Name: job_title, Length: 1140, dtype: object

# %%
sd1 = pd.read_csv("engage_20240429_225800.csv")

# %%
sd2 = pd.read_csv("engage_20240429_231608.csv")

# %%
sd1
# Out:
#                                               job_title  \
# 0                           営業【月給29万以上！インセンティブ有！未経験OK！】
# 1                                 不動産営業（賃貸仲介・賃貸管理・売買仲介）
# 2                                            カウンターにて接客業
# 3                         内定まで2週間！未経験OK！賃貸不動産のルームアドバイザー
# 4                                  営業（不動産賃貸売買仲介・賃貸物件管理）
# ...                                                 ...
# 1135   技術アジャスター（自動車事故の調査など）完全週休２日制、土日休　■勤務地：山梨県他（全国拠点有）
# 1136  100％反響営業！テレアポなし◎リゾート物件の仲介/業績賞与年3回！テレワーク需要で好調♪未...
# 1137                           宮崎県で大手企業の新規事業立ち上げのサポート業務
# 1138  転職したら毎日に余裕ができた／年休126日（土日OK）／ほぼ毎日18時半退社／賃貸管理∋宇都...
# 1139  ★長崎北店勤務★テレアポ・飛び込み一切なし！100％問い合わせ対応の【完全反響型営業】※原則...
#
#                 company_name          work_genre           area  \
# 0             Only Life 株式会社                法人営業  ('北海道札幌市北区',)
# 1            有限会社ハウスコーポレーション               不動産営業    ('兵庫県尼崎市',)
# 2            有限会社ハウスコーポレーション           カウンター賃貸営業    ('兵庫県尼崎市',)
# 3            有限会社ハウスコーポレーション             カウンター営業    ('兵庫県尼崎市',)
# 4            有限会社ハウスコーポレーション             カウンター営業    ('兵庫県尼崎市',)
# ...                      ...                 ...            ...
# 1135      あいおいニッセイ同和損害調査株式会社            技術アジャスター    ('山梨県甲府市',)
# 1136           ロイヤルハウジンググループ           不動産売買仲介営業    ('静岡県伊東市',)
# 1137  PhillipsConsulting株式会社  新規事業の立ち上げに関わる責任者候補    ('宮崎県宮崎市',)
# 1138               株式会社ミニテック          賃貸経営アドバイザー   ('栃木県宇都宮市',)
# 1139                  リック不動産              営業スタッフ    ('長崎県長崎市',)
#
#                       income  \
# 0       ('月給 29万円 ～ 100万円',)
# 1             ('月給 25万円 ～',)
# 2        ('月給 25万円 ～ 40万円',)
# 3        ('月給 25万円 ～ 80万円',)
# 4        ('月給 25万円 ～ 40万円',)
# ...                      ...
# 1135     ('月給 22万4,000円 ～',)
# 1136     ('月給 24万5,000円 ～',)
# 1137  ('日給 1万円 ～ 1万6,000円',)
# 1138     ('月給 23万円 ～ 26万円',)
# 1139     ('月給 22万円 ～ 27万円',)
#
#                                             description  \
# 0     ◎未経験の方には\n\nあなたのレベルに合わせて、簡単なお仕事からスタート。\n\n3~6ヶ...
# 1     カウンター営業\n\nインターネットや住宅情報誌等を見て来店頂いたお客様への、売買物件の紹介...
# 2     [1]カウンター営業\n\nインターネットや住宅情報誌等を見て来店頂いたお客様への、賃貸・売...
# 3     カウンター営業\n\nインターネットや住宅情報誌等を見て来店頂いたお客様への、売買物件の紹介...
# 4     インターネットや住宅情報誌等を見て来店頂いたお客様への、賃貸・売買物件の紹介や案内業務。※反...
# ...                                                 ...
# 1135  ▼事故解決をサポートします。\n\nあなたにお任せするのは、自動車保険に関する損害調査業務。...
# 1136  ☆創業448年！だから100％反響営業で大丈夫なんです。\n\n☆研修・サポート充実だから2...
# 1137  ◎未経験者大歓迎\n\n未経験でも、将来的に、大手企業のコンサルティングを行っていただける為...
# 1138  ▼ほぼ定時帰り！繁忙期を除くと、残業時間は忙し店舗でも1日最長1時間ほどです\n▼ほとんどの...
# 1139  ■賃貸営業（100％反響・来店型営業）\n\n　お部屋探しに来店されたお客様にお部屋をご案内...
#
#                                                     url              job_type
# 0     https://en-gage.net/user/search/?area=0&job=10...                   営業系
# 1     https://en-gage.net/user/search/?area=0&job=10...                   営業系
# 2     https://en-gage.net/user/search/?area=0&job=10...                   営業系
# 3     https://en-gage.net/user/search/?area=0&job=10...                   営業系
# 4     https://en-gage.net/user/search/?area=0&job=10...                   営業系
# ...                                                 ...                   ...
# 1135  https://en-gage.net/user/search/?area=0&job=30...  専門職系（コンサルタント、金融、不動産）
# 1136  https://en-gage.net/user/search/?area=0&job=30...  専門職系（コンサルタント、金融、不動産）
# 1137  https://en-gage.net/user/search/?area=0&job=30...  専門職系（コンサルタント、金融、不動産）
# 1138  https://en-gage.net/user/search/?area=0&job=30...  専門職系（コンサルタント、金融、不動産）
# 1139  https://en-gage.net/user/search/?area=0&job=30...  専門職系（コンサルタント、金融、不動産）
#
# [1140 rows x 8 columns]

# %%
engage = pd.concat([sd1, sd2], axis=0)

# %%
engage
# Out:
#                                  job_title            company_name work_genre  \
# 0              営業【月給29万以上！インセンティブ有！未経験OK！】          Only Life 株式会社       法人営業
# 1                    不動産営業（賃貸仲介・賃貸管理・売買仲介）         有限会社ハウスコーポレーション      不動産営業
# 2                               カウンターにて接客業         有限会社ハウスコーポレーション  カウンター賃貸営業
# 3            内定まで2週間！未経験OK！賃貸不動産のルームアドバイザー         有限会社ハウスコーポレーション    カウンター営業
# 4                     営業（不動産賃貸売買仲介・賃貸物件管理）         有限会社ハウスコーポレーション    カウンター営業
# ...                                    ...                     ...        ...
# 1675  (久喜市)無資格未経験歓迎 日常生活アシスタント日給パート(男女応募可)                （特定）広域協会     福祉スタッフ
# 1676      急募【非常勤さん募集】幼稚園教諭・保育士のクラス補助や預かり保育               相模ひまわり幼稚園      幼稚園教諭
# 1677              国内事業部 フィールド・ロジスティシャン募集！！  特定非営利活動法人　ピースウィンズ・ジャパン      NPO職員
# 1678                               事務(パート）              学校法人ミズモト学園       事務職員
# 1679       未経験OK！完全土日祝休み！ＪＦ共水連（舞鶴市勤務）/面接2回          全国共済水産業協同組合連合会     共済団体職員
#
#                   area                         income  \
# 0        ('北海道札幌市北区',)           ('月給 29万円 ～ 100万円',)
# 1          ('兵庫県尼崎市',)                 ('月給 25万円 ～',)
# 2          ('兵庫県尼崎市',)            ('月給 25万円 ～ 40万円',)
# 3          ('兵庫県尼崎市',)            ('月給 25万円 ～ 80万円',)
# 4          ('兵庫県尼崎市',)            ('月給 25万円 ～ 40万円',)
# ...                ...                            ...
# 1675       ('埼玉県久喜市',)    ('日給 1万8,100円 ～ 2万1,720円',)
# 1676   ('神奈川県相模原市南区',)               ('時給 1,200円 ～',)
# 1677  ('広島県神石郡神石高原町',)            ('月給 20万円 ～ 45万円',)
# 1678     ('静岡県浜松市中区',)        ('時給 1,000円 ～ 1,200円',)
# 1679       ('京都府舞鶴市',)  ('月給 18万7,471円 ～ 25万9,015円',)
#
#                                             description  \
# 0     ◎未経験の方には\n\nあなたのレベルに合わせて、簡単なお仕事からスタート。\n\n3~6ヶ...
# 1     カウンター営業\n\nインターネットや住宅情報誌等を見て来店頂いたお客様への、売買物件の紹介...
# 2     [1]カウンター営業\n\nインターネットや住宅情報誌等を見て来店頂いたお客様への、賃貸・売...
# 3     カウンター営業\n\nインターネットや住宅情報誌等を見て来店頂いたお客様への、売買物件の紹介...
# 4     インターネットや住宅情報誌等を見て来店頂いたお客様への、賃貸・売買物件の紹介や案内業務。※反...
# ...                                                 ...
# 1675  ※週３以上できる方、日勤夜勤両方できる方限定\n\n\n\n家族と同居している男性身障者(四...
# 1676  0歳~小学６年生まで幅広い働き方がございます。\n\n\n\n【メインとなる仕事】\n\n☆...
# 1677  【具体的には】\n\n・災害現場での安全管理\n\n・災害現場での関係機関との連絡・調整\n...
# 1678  業務内容\n\n・学校事務\n\n（エクセル・ワード・パワーポイント・SNS等の入力作業等）...
# 1679  漁業協同組合の組合員さま一人ひとりが笑顔で安心して働けるように…。\n\n私たちと一緒に”浜...
#
#                                                     url      job_type
# 0     https://en-gage.net/user/search/?area=0&job=10...           営業系
# 1     https://en-gage.net/user/search/?area=0&job=10...           営業系
# 2     https://en-gage.net/user/search/?area=0&job=10...           営業系
# 3     https://en-gage.net/user/search/?area=0&job=10...           営業系
# 4     https://en-gage.net/user/search/?area=0&job=10...           営業系
# ...                                                 ...           ...
# 1675  https://en-gage.net/user/search/?area=0&job=65...  公務員、団体職員、その他
# 1676  https://en-gage.net/user/search/?area=0&job=65...  公務員、団体職員、その他
# 1677  https://en-gage.net/user/search/?area=0&job=65...  公務員、団体職員、その他
# 1678  https://en-gage.net/user/search/?area=0&job=65...  公務員、団体職員、その他
# 1679  https://en-gage.net/user/search/?area=0&job=65...  公務員、団体職員、その他
#
# [2820 rows x 8 columns]

# %%
category_counts = engage['job_type'].value_counts()

# %%
category_counts
# Out:
# job_type
# 企画・事務・管理系                240
# 販売・接客・サービス系              240
# 専門サービス系（医療、福祉、教育、その他）    240
# 専門職系（コンサルタント、金融、不動産）     240
# クリエイティブ系                 240
# 技術系（IT・Web・ゲーム・通信）       240
# 技術系（電気、電子、機械）            240
# 技術系（建築、土木）               240
# 技術系（医薬、化学、素材、食品）         240
# 警備、清掃、設備管理、運輸・配送、軽作業系    240
# 公務員、団体職員、その他             240
# 営業系                      180
# Name: count, dtype: int64

# %% [markdown]
# # General feature identification:
# ### Analyze the data to identify patterns or common features across job postings. This could include common job titles, industries, salary ranges, etc.

# %% [markdown]
# # Cアイデア (中分類) (Business Needs):
#
# ### Explore the business needs reflected in the job postings. Are there specific skills or roles that are in high demand? What industries or sectors are actively hiring?

# %% [markdown]
# # Eニーズの根拠 (Basis of Needs):

# %% [markdown]
# Determine the basis for identified needs using the data. What specific data points or trends support the identified business needs?

# %% [markdown]
# # D生成の強み (Strengths of AI Generation):

# %% [markdown]
# Evaluate the potential strengths of using AI for generating project ideas based on the analyzed data. For example, can AI help identify emerging trends or niche areas of opportunity?
